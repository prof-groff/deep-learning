# %% [markdown]
# ## Deep Learning Completely Inelastic Collision Solver
#
# This notebook implements a recurrent neural network to solve for the post collision velocity of a two-mass system where the collision is completely inelastic and the second mass is initially at rest. The model is formulated using a recurrent neural network (RNN) and its input is represented as a text string giving the masses and the initial velocity of the first mass. Exact solutions calculated using conservation of momentum equations are used to train the RNN and evaluate the accuracy of predictions. This notebook is inspired by the addition_rnn.py example included with Keras.

# %% [markdown]
# ### Import useful packaged including TensorFlow 2.0 and Keras.
# The notebook utilizes tensorflow >= 2.0, which now includes keras, a package of high level wrappers designed to make building and training deep learning models easier.

# %%
# import packages
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

from tensorflow.keras.layers import RNN, LSTM, TimeDistributed, RepeatVector, Dense, LSTMCell, Dropout
# LSTM doesn't work well since cuDNN is compiled with certain restrictions. 
# So, here I will create LSTM layers by wrapping LSTMCell in RNN
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers

import pickle
import os

# %% [markdown]
# ### Check to see if a Tensorflow is installed with GPU support and if a GPU is available.

# %%
if not tf.test.is_gpu_available():
    print('No GPU found. Training will be slower.')
else:
    print('Default GPU {} found.'.format(tf.test.gpu_device_name()))
# Out:
# Default GPU /device:GPU:0 found.

# %% [markdown]
# ### Define a class to encode and decode between a selection of characters and one-hot integer representations.

# %%
class CharacterTable(object):
    """Given a set of characters:
    + Encode them to a one-hot integer representation
    + Decode the one-hot or integer representation to their character output
    + Decode a vector of probabilities to their character output
    """
    def __init__(self, chars):
        """Initialize character table.
        # Arguments
            chars: Characters that can appear in the input.
        """
        self.chars = sorted(set(chars))
        self.char_indices = dict((c, i) for i, c in enumerate(self.chars))
        self.indices_char = dict((i, c) for i, c in enumerate(self.chars))

    def encode(self, C, num_rows):
        """One-hot encode given string C.
        # Arguments
            C: string, to be encoded.
            num_rows: Number of rows in the returned one-hot encoding. This is
                used to keep the # of rows for each data the same.
        """
        x = np.zeros((num_rows, len(self.chars)))
        for i, c in enumerate(C):
            x[i, self.char_indices[c]] = 1
        return x

    def decode(self, x, calc_argmax=True):
        """Decode the given vector or 2D array to their character output.
        # Arguments
            x: A vector or a 2D array of probabilities or one-hot representations;
                or a vector of character indices (used with `calc_argmax=False`).
            calc_argmax: Whether to find the character index with maximum
                probability, defaults to `True`.
        """
        if calc_argmax:
            x = x.argmax(axis=-1)
        return ''.join(self.indices_char[x] for x in x)
    
class colors:
    ok = '\033[92m'
    fail = '\033[91m'
    close = '\033[0m'

# %% [markdown]
# ### Generate input and output character sequences.
#
# The input is in the form {}m{}v{} where the values in the {}s are randomly drawn one or two character sequences representing, from left to right, the mass of object one, the mass of object two, and the initial velocity of object one. Object two is initially at rest.
#
# The output is a character string representing the post collision velocity of the system after a head on totally inelastic collision.

# %%
# Parameters for the model and dataset.
num_problems = 80000 # number of sequences in the training and validation sets
digits = 2 # maximum number of digits for mass and velocity in the input sequence 
lenans = 4 # number of characters in the answer sequence 

REVERSE=False

# Maximum length of input is 'int + int' (e.g., '345+678'). Maximum length of
# int is DIGITS.
maxlen = digits + 1 + digits + 1 + digits

# All the numbers, plus sign and space for padding.
chars = '0123456789mv. '
ctable = CharacterTable(chars)


filename = 'dl-completely-inelastic-collison-rnn-data.pickle'

if os.path.exists(filename):
    print('Loading saved data...')
    with open(filename, 'rb') as f:
        questions, expected, x_train, x_val, x_test, y_train, y_val, y_test = pickle.load(f)
        
else:


    questions = []
    expected = []
    seen = set()
    print('Generating data...')
    while len(questions) < num_problems:
        f = lambda: int(''.join(np.random.choice(list('123456789'))
                    for i in np.arange(np.random.randint(1, digits + 1))))
        a, b, c = f(), f(), f()
        # Skip any questions we've already seen
        key = tuple(sorted((a, b, c)))
        if key in seen:
            continue
        seen.add(key)
        # Pad the data with spaces such that it is always MAXLEN.
        q = '{}m{}v{}'.format(a, b, c)
        query = q + ' ' * (maxlen - len(q))
        ans = a*c/(a+b)
        if ans < 10:
            r = lenans-2
        elif ans < 100:
            r = lenans-3
        ans = str(round(a*c/(a+b),r))
        # Answers can be of maximum size LENANS.
        ans += '0' * (lenans - len(ans))
        questions.append(query)
        expected.append(ans)
    print('Total momentum questions:', len(questions))

    print('Vectorization...')
    x = np.zeros((len(questions), maxlen, len(chars)), dtype=np.bool)
    y = np.zeros((len(questions), lenans, len(chars)), dtype=np.bool)
    for i, sentence in enumerate(questions):
        x[i] = ctable.encode(sentence, maxlen)
    for i, sentence in enumerate(expected):
        y[i] = ctable.encode(sentence, lenans)

    # Shuffle (x, y) in unison as the later parts of x will almost all be larger
    # digits.
    indices = np.arange(len(y))
    np.random.shuffle(indices)
    x = x[indices]
    y = y[indices]

    # set apart 20% for validation and text data that we never train over.
    split_at = len(x) - len(x) // 5
    (x_train, x_val) = x[:split_at], x[split_at:]
    (y_train, y_val) = y[:split_at], y[split_at:]

    split_at =  len(x_val) - len(x_val) // 2 
    (x_val, x_test) = x_val[:split_at], x_val[split_at:]
    (y_val, y_test) = y_val[:split_at], y_val[split_at:]
    
    with open(filename, 'wb') as f:
        print('Saving data...')
        pickle.dump([questions, expected, x_train, x_val, x_test, y_train, y_val, y_test], f)

print('Training Data:')
print(x_train.shape)
print(y_train.shape)

print('Validation Data:')
print(x_val.shape)
print(y_val.shape)

print('Test Data:')
print(x_test.shape)
print(y_test.shape)
# Out:
# Loading saved data...
# Training Data:
# (64000, 8, 14)
# (64000, 4, 14)
# Validation Data:
# (8000, 8, 14)
# (8000, 4, 14)
# Test Data:
# (8000, 8, 14)
# (8000, 4, 14)

# %%
# show an example of the input and output character strings
ii = np.random.randint(0, 1000)
print('input:', questions[ii], 'output:', expected[ii])
# Out:
# input: 88m48v86 output: 55.6

# %%
# hyperparameters 
HIDDEN_SIZE = 128
BATCH_SIZE = 256
LAYERS = 2
learning_rate = 0.001

print('Build model...')
model = Sequential()
# "encode" the input sequence using an RNN, producing an output of HIDDEN_SIZE.
# note: in a situation where your input sequences have a variable length, use input_shape=(None, num_feature).
# model.add(LSTM(HIDDEN_SIZE, input_shape=(MAXLEN, len(chars))))
model.add(RNN(LSTMCell(HIDDEN_SIZE), input_shape=(maxlen, len(chars))))

# as the decoder RNN's input, repeatedly provide with the last output of
# RNN for each time step. Repeat 'lenans' times as that's the maximum length of output.
model.add(RepeatVector(lenans))
# the decoder RNN could be multiple layers stacked or a single layer.
for _ in range(LAYERS):
    # by setting return_sequences to True, return not only the last output but
    # all the outputs so far in the form of (num_samples, timesteps,
    # output_dim). This is necessary as TimeDistributed in the below expects
    # the first dimension to be the timesteps.
    # model.add(LSTM(HIDDEN_SIZE, return_sequences=True))
    model.add(RNN(LSTMCell(HIDDEN_SIZE), return_sequences=True))

# add a dropout layer to prevent overfitting
# model.add(Dropout(rate=0.1))
# add a dense layer to every temporal slice of an input. for each of step of the output sequence, 
# decide which character should be chosen.
model.add(TimeDistributed(Dense(len(chars), activation='softmax')))
model.compile(loss='categorical_crossentropy',
              # optimizer=keras.optimizers.Adam(lr=learning_rate),
              optomizer=keras.optimizers.Adam(),
              metrics=['accuracy'])
model.summary()
# Out:
# Build model...
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rnn (RNN)                    (None, 128)               73216
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 4, 128)            0
# _________________________________________________________________
# rnn_1 (RNN)                  (None, 4, 128)            131584
# _________________________________________________________________
# rnn_2 (RNN)                  (None, 4, 128)            131584
# _________________________________________________________________
# time_distributed (TimeDistri (None, 4, 14)             1806
# =================================================================
# Total params: 338,190
# Trainable params: 338,190
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model and generate example predictions every 3 epochs.

# %%
# train the model and show predictions against the validation dataset.
for iteration in range(1, 36):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(x_train, y_train,
              batch_size=BATCH_SIZE,
              epochs=3,
              validation_data=(x_val, y_val))
    score = model.evaluate(x_test, y_test, verbose=0)
    print('score:', score)
    # select 10 samples from the validation set at random so we can visualize errors.
    for i in range(10):
        ind = np.random.randint(0, len(x_val))
        rowx, rowy = x_test[np.array([ind])], y_test[np.array([ind])]
        preds = model.predict_classes(1.0*rowx, verbose=0) # mult by 1.0 to get data types to jive
        q = ctable.decode(rowx[0])
        correct = ctable.decode(rowy[0])
        guess = ctable.decode(preds[0], calc_argmax=False)
        print('Q', q[::-1] if REVERSE else q, end=' ')
        print('A', correct, end=' ')
        
        for ii in np.arange(len(correct)):
            if correct[ii] == guess[ii]:
                print(colors.ok + '☑' + colors.close, end='')
            else:
                print(colors.fail + '☒' + colors.close, end='')
        
        print(' P', guess)
# Out:
# --------------------------------------------------
# Iteration 1
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 8s 124us/sample - loss: 2.0321 - accuracy: 0.3191 - val_loss: 1.8965 - val_accuracy: 0.3427
# Epoch 2/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 1.8265 - accuracy: 0.3579 - val_loss: 1.7760 - val_accuracy: 0.3536
# Epoch 3/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 1.6555 - accuracy: 0.3870 - val_loss: 1.6215 - val_accuracy: 0.3739
# score: [1.6199826693534851, 0.376375]
# Q 33m24v42 A 24.3 ☒☒☑☑ P 19.3
# Q 37m8v42  A 34.5 ☒☒☑☒ P 12.0
# Q 3m76v71  A 2.70 ☒☑☒☑ P 0.00
# Q 63m72v47 A 21.9 ☒☒☑☒ P 13.3
# Q 95m77v7  A 3.87 ☒☑☒☒ P 1.90
# Q 67m96v54 A 22.2 ☒☒☑☒ P 13.3
# Q 31m58v28 A 9.75 ☒☑☒☒ P 1.90
# Q 19m6v15  A 11.4 ☑☒☑☒ P 1..0
# Q 68m25v71 A 51.9 ☒☒☑☒ P 33.3
# Q 41m89v5  A 1.58 ☑☑☒☒ P 1.30
#
# --------------------------------------------------
# Iteration 2
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 1.5199 - accuracy: 0.4203 - val_loss: 1.4442 - val_accuracy: 0.4414
# Epoch 2/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 1.4289 - accuracy: 0.4527 - val_loss: 1.4013 - val_accuracy: 0.4471
# Epoch 3/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 1.3677 - accuracy: 0.4721 - val_loss: 1.3100 - val_accuracy: 0.5055
# score: [1.3140086183547974, 0.50303125]
# Q 96m89v57 A 29.6 ☑☑☑☒ P 29.1
# Q 75m51v14 A 8.33 ☒☑☒☒ P 7.80
# Q 29m15v71 A 46.8 ☑☒☑☒ P 45.1
# Q 74m34v7  A 4.80 ☑☑☒☑ P 4.10
# Q 59m42v75 A 43.8 ☑☒☑☒ P 45.1
# Q 15m8v84  A 54.8 ☑☒☑☒ P 59.1
# Q 13m82v43 A 5.88 ☒☑☒☒ P 6.10
# Q 4m99v76  A 2.95 ☒☑☒☒ P 3.61
# Q 56m29v14 A 9.22 ☒☑☒☒ P 1..1
# Q 4m17v43  A 8.19 ☒☑☒☒ P 7.80
#
# --------------------------------------------------
# Iteration 3
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 1.3234 - accuracy: 0.4876 - val_loss: 1.2962 - val_accuracy: 0.4993
# Epoch 2/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 1.2898 - accuracy: 0.5003 - val_loss: 1.3027 - val_accuracy: 0.4965
# Epoch 3/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 1.2602 - accuracy: 0.5110 - val_loss: 1.3492 - val_accuracy: 0.4789
# score: [1.361320212841034, 0.47359374]
# Q 29m64v1  A 0.31 ☑☑☒☒ P 0.48
# Q 82m36v12 A 8.34 ☒☑☒☒ P 9..3
# Q 25m76v29 A 7.18 ☒☑☒☒ P 9.80
# Q 98m11v15 A 13.5 ☑☑☑☒ P 13.3
# Q 91m66v64 A 37.1 ☑☒☑☒ P 34.5
# Q 45m19v29 A 20.4 ☑☒☑☒ P 21.5
# Q 51m9v88  A 74.8 ☑☒☑☒ P 70.1
# Q 7m17v79  A 23.0 ☑☒☑☒ P 24.3
# Q 6m34v88  A 13.2 ☑☒☑☒ P 12.3
# Q 99m61v2  A 1.24 ☑☑☒☒ P 1.83
#
# --------------------------------------------------
# Iteration 4
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 1.2390 - accuracy: 0.5171 - val_loss: 1.2261 - val_accuracy: 0.5250
# Epoch 2/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 1.2183 - accuracy: 0.5254 - val_loss: 1.2822 - val_accuracy: 0.4906
# Epoch 3/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 1.1995 - accuracy: 0.5305 - val_loss: 1.1720 - val_accuracy: 0.5430
# score: [1.1725877141952514, 0.54484373]
# Q 26m58v92 A 28.5 ☑☒☑☒ P 29.9
# Q 37m68v16 A 5.64 ☑☑☒☒ P 5.90
# Q 4m35v71  A 7.28 ☑☑☒☒ P 7.00
# Q 54m97v7  A 2.50 ☑☑☒☒ P 2.96
# Q 66m89v88 A 37.5 ☒☒☑☒ P 44.9
# Q 33m27v78 A 42.9 ☑☒☑☑ P 44.9
# Q 5m64v1   A 0.07 ☑☑☑☒ P 0.09
# Q 23m94v69 A 13.6 ☑☑☑☒ P 13.9
# Q 27m5v95  A 80.2 ☑☒☑☒ P 89.9
# Q 75m37v2  A 1.34 ☑☑☒☒ P 1.99
#
# --------------------------------------------------
# Iteration 5
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 1.1819 - accuracy: 0.5366 - val_loss: 1.1197 - val_accuracy: 0.5762
# Epoch 2/3
# 64000/64000 [==============================] - 3s 54us/sample - loss: 1.1634 - accuracy: 0.5430 - val_loss: 1.1377 - val_accuracy: 0.5548
# Epoch 3/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 1.1463 - accuracy: 0.5492 - val_loss: 1.1795 - val_accuracy: 0.5284
# score: [1.1787586469650269, 0.53028125]
# Q 76m48v59 A 36.2 ☑☒☑☒ P 37.1
# Q 57m3v16  A 15.2 ☑☒☑☒ P 16.8
# Q 97m73v99 A 56.5 ☒☒☑☒ P 60.9
# Q 8m66v86  A 9.30 ☒☑☒☑ P 8.00
# Q 56m33v37 A 23.3 ☑☒☑☒ P 24.1
# Q 44m85v56 A 19.1 ☑☒☑☑ P 18.1
# Q 17m97v38 A 5.67 ☒☑☒☒ P 4.00
# Q 91m87v47 A 24.0 ☑☒☑☒ P 25.1
# Q 73m77v84 A 40.9 ☑☒☑☒ P 42.1
# Q 87m82v12 A 6.18 ☑☑☒☒ P 6.41
#
# --------------------------------------------------
# Iteration 6
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 1.1304 - accuracy: 0.5561 - val_loss: 1.1099 - val_accuracy: 0.5683
# Epoch 2/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 1.1149 - accuracy: 0.5603 - val_loss: 1.0835 - val_accuracy: 0.5777
# Epoch 3/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 1.1027 - accuracy: 0.5652 - val_loss: 1.0626 - val_accuracy: 0.5887
# score: [1.065936355829239, 0.58825]
# Q 19m56v55 A 13.9 ☑☒☑☒ P 14.5
# Q 86m74v83 A 44.6 ☑☒☑☒ P 45.5
# Q 49m93v21 A 7.25 ☑☑☒☒ P 7.00
# Q 84m35v15 A 10.6 ☑☑☑☒ P 10.3
# Q 8m86v27  A 2.30 ☑☑☒☑ P 2.70
# Q 73m21v54 A 41.9 ☑☒☑☒ P 44.5
# Q 38m32v52 A 28.2 ☑☒☑☒ P 29.5
# Q 45m99v88 A 27.5 ☑☑☑☑ P 27.5
# Q 43m1v8   A 7.82 ☒☑☑☒ P 8.80
# Q 56m48v59 A 31.8 ☑☒☑☒ P 32.5
#
# --------------------------------------------------
# Iteration 7
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 1.0891 - accuracy: 0.5712 - val_loss: 1.0701 - val_accuracy: 0.5788
# Epoch 2/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 1.0773 - accuracy: 0.5734 - val_loss: 1.0440 - val_accuracy: 0.5931
# Epoch 3/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 1.0656 - accuracy: 0.5776 - val_loss: 1.0931 - val_accuracy: 0.5681
# score: [1.0961573090553283, 0.5675]
# Q 89m29v88 A 66.4 ☑☒☑☒ P 68.3
# Q 27m76v13 A 3.41 ☑☑☒☒ P 3.00
# Q 6m28v4   A 0.71 ☑☑☒☒ P 0.60
# Q 96m29v83 A 63.7 ☑☒☑☒ P 68.3
# Q 8m72v41  A 4.10 ☑☑☒☑ P 4.00
# Q 75m9v36  A 32.1 ☑☒☑☒ P 31.0
# Q 94m37v25 A 17.9 ☑☑☑☒ P 17.0
# Q 55m62v31 A 14.6 ☑☑☑☒ P 14.0
# Q 95m16v63 A 53.9 ☑☒☑☒ P 58.3
# Q 53m57v14 A 6.75 ☑☑☒☒ P 6.00
#
# --------------------------------------------------
# Iteration 8
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 1.0537 - accuracy: 0.5824 - val_loss: 1.1189 - val_accuracy: 0.5570
# Epoch 2/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 1.0446 - accuracy: 0.5871 - val_loss: 1.0144 - val_accuracy: 0.5915
# Epoch 3/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 1.0350 - accuracy: 0.5903 - val_loss: 1.0652 - val_accuracy: 0.5767
# score: [1.0746028776168823, 0.5726875]
# Q 16m88v17 A 2.62 ☒☑☒☒ P 3.88
# Q 37m21v34 A 21.7 ☑☒☑☒ P 22.8
# Q 78m81v74 A 36.3 ☑☑☑☒ P 36.8
# Q 3m94v21  A 0.65 ☑☑☒☒ P 0.88
# Q 41m5v18  A 16.0 ☑☑☑☒ P 16.2
# Q 55m93v36 A 13.4 ☑☑☑☒ P 13.2
# Q 57m93v82 A 31.2 ☑☑☑☒ P 31.8
# Q 33m26v5  A 2.80 ☑☑☑☑ P 2.80
# Q 72m81v21 A 9.88 ☒☒☒☒ P 10.3
# Q 71m18v6  A 4.79 ☑☑☒☒ P 4.38
#
# --------------------------------------------------
# Iteration 9
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 54us/sample - loss: 1.0268 - accuracy: 0.5940 - val_loss: 0.9998 - val_accuracy: 0.6087
# Epoch 2/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 1.0182 - accuracy: 0.5960 - val_loss: 0.9823 - val_accuracy: 0.6092
# Epoch 3/3
# 64000/64000 [==============================] - 3s 54us/sample - loss: 1.0089 - accuracy: 0.6006 - val_loss: 1.0052 - val_accuracy: 0.5973
# score: [1.0045805442333222, 0.59984374]
# Q 7m36v57  A 9.28 ☑☑☒☒ P 9..0
# Q 27m38v2  A 0.83 ☑☑☑☒ P 0.86
# Q 83m22v99 A 78.3 ☑☒☑☒ P 71.6
# Q 96m63v98 A 59.2 ☒☒☑☒ P 61.6
# Q 73m55v47 A 26.8 ☑☒☑☒ P 27.6
# Q 44m31v4  A 2.35 ☑☑☒☒ P 2.00
# Q 21m76v78 A 16.9 ☑☑☑☒ P 16.6
# Q 49m45v44 A 22.9 ☑☒☑☒ P 23.6
# Q 64m97v97 A 38.6 ☑☒☑☒ P 39.5
# Q 67m88v79 A 34.1 ☑☒☑☒ P 35.5
#
# --------------------------------------------------
# Iteration 10
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 1.0007 - accuracy: 0.6053 - val_loss: 0.9871 - val_accuracy: 0.5966
# Epoch 2/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.9945 - accuracy: 0.6061 - val_loss: 1.0050 - val_accuracy: 0.6009
# Epoch 3/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.9848 - accuracy: 0.6096 - val_loss: 1.0440 - val_accuracy: 0.5829
# score: [1.052202639579773, 0.5819687]
# Q 39m81v17 A 5.53 ☑☑☒☒ P 5.44
# Q 37m25v9  A 5.37 ☑☑☒☒ P 5.40
# Q 19m53v8  A 2.11 ☒☑☒☒ P 1.90
# Q 23m1v66  A 63.2 ☑☑☑☒ P 63.3
# Q 93m11v14 A 12.5 ☑☑☑☒ P 12.3
# Q 54m11v4  A 3.32 ☑☑☒☒ P 3.44
# Q 79m58v58 A 33.4 ☑☒☑☒ P 34.5
# Q 7m29v76  A 14.8 ☑☒☑☑ P 15.8
# Q 56m45v97 A 53.8 ☑☒☑☒ P 55.5
# Q 47m73v5  A 1.96 ☑☑☒☒ P 1.80
#
# --------------------------------------------------
# Iteration 11
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.9786 - accuracy: 0.6130 - val_loss: 0.9788 - val_accuracy: 0.6103
# Epoch 2/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.9725 - accuracy: 0.6151 - val_loss: 0.9219 - val_accuracy: 0.6428
# Epoch 3/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.9664 - accuracy: 0.6171 - val_loss: 0.9453 - val_accuracy: 0.6259
# score: [0.9489419858455658, 0.622625]
# Q 56m96v54 A 19.9 ☑☑☑☒ P 19.2
# Q 64m18v12 A 9.37 ☑☑☑☒ P 9.32
# Q 65m78v76 A 34.5 ☑☑☑☑ P 34.5
# Q 71m72v47 A 23.3 ☑☑☑☒ P 23.0
# Q 72m37v69 A 45.6 ☑☒☑☒ P 46.0
# Q 36m36v52 A 26.0 ☑☒☑☑ P 25.0
# Q 82m91v5  A 2.37 ☑☑☒☒ P 2.40
# Q 13m46v2  A 0.44 ☑☑☒☒ P 0.37
# Q 85m7v55  A 50.8 ☑☑☑☑ P 50.8
# Q 28m52v82 A 28.7 ☑☑☑☒ P 28.0
#
# --------------------------------------------------
# Iteration 12
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.9601 - accuracy: 0.6194 - val_loss: 0.9248 - val_accuracy: 0.6334
# Epoch 2/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.9532 - accuracy: 0.6243 - val_loss: 0.9494 - val_accuracy: 0.6240
# Epoch 3/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.9490 - accuracy: 0.6253 - val_loss: 0.9090 - val_accuracy: 0.6421
# score: [0.9112844998836518, 0.6435625]
# Q 89m35v37 A 26.6 ☑☑☑☒ P 26.1
# Q 3m88v62  A 2.04 ☑☑☒☒ P 2.22
# Q 91m91v74 A 37.0 ☑☒☑☒ P 36.1
# Q 18m9v17  A 11.3 ☑☑☑☒ P 11.9
# Q 12m47v84 A 17.1 ☑☑☑☒ P 17.5
# Q 22m2v58  A 53.2 ☑☑☑☒ P 53.9
# Q 13m97v12 A 1.42 ☑☑☒☒ P 1.66
# Q 2m45v57  A 2.43 ☑☑☑☒ P 2.40
# Q 9m27v63  A 15.8 ☑☒☑☒ P 16.2
# Q 4m44v29  A 2.42 ☑☑☒☒ P 2.50
#
# --------------------------------------------------
# Iteration 13
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.9454 - accuracy: 0.6268 - val_loss: 0.9364 - val_accuracy: 0.6258
# Epoch 2/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.9391 - accuracy: 0.6280 - val_loss: 0.9292 - val_accuracy: 0.6334
# Epoch 3/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.9355 - accuracy: 0.6290 - val_loss: 0.9087 - val_accuracy: 0.6361
# score: [0.9101541342735291, 0.63596874]
# Q 29m84v4  A 1.03 ☑☑☑☒ P 1.06
# Q 75m94v9  A 3.99 ☑☑☒☒ P 3.00
# Q 62m89v83 A 34.1 ☑☒☑☒ P 33.0
# Q 45m33v57 A 32.9 ☑☑☑☒ P 32.0
# Q 26m86v4  A 0.93 ☑☑☒☒ P 0.86
# Q 73m85v85 A 39.3 ☑☑☑☒ P 39.0
# Q 7m38v79  A 12.3 ☑☑☑☒ P 12.0
# Q 48m1v57  A 55.8 ☑☒☑☒ P 56.1
# Q 39m81v17 A 5.53 ☑☑☒☒ P 5.00
# Q 78m26v69 A 51.8 ☑☑☑☒ P 51.0
#
# --------------------------------------------------
# Iteration 14
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.9293 - accuracy: 0.6324 - val_loss: 0.8929 - val_accuracy: 0.6466
# Epoch 2/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.9242 - accuracy: 0.6348 - val_loss: 0.9530 - val_accuracy: 0.6292
# Epoch 3/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.9213 - accuracy: 0.6360 - val_loss: 0.9350 - val_accuracy: 0.6235
# score: [0.9349445757865906, 0.6245625]
# Q 7m75v6   A 0.51 ☑☑☒☒ P 0.49
# Q 47m7v79  A 68.8 ☑☒☑☒ P 69.6
# Q 59m11v82 A 69.1 ☒☒☑☒ P 70.0
# Q 88m79v28 A 14.8 ☑☒☑☒ P 15.2
# Q 1m76v78  A 1.01 ☒☑☒☒ P 0.94
# Q 62m45v87 A 50.4 ☑☑☑☒ P 50.0
# Q 78m47v53 A 33.1 ☑☒☑☒ P 34.0
# Q 5m75v38  A 2.38 ☑☑☒☒ P 2.22
# Q 59m17v98 A 76.1 ☑☒☑☒ P 70.0
# Q 27m64v8  A 2.37 ☑☑☒☒ P 2.20
#
# --------------------------------------------------
# Iteration 15
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.9155 - accuracy: 0.6396 - val_loss: 0.9545 - val_accuracy: 0.6172
# Epoch 2/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.9117 - accuracy: 0.6403 - val_loss: 0.9083 - val_accuracy: 0.6378
# Epoch 3/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.9078 - accuracy: 0.6420 - val_loss: 0.9128 - val_accuracy: 0.6328
# score: [0.9121813957691193, 0.63509375]
# Q 42m72v49 A 18.1 ☑☒☑☒ P 17.5
# Q 8m89v38  A 3.13 ☑☑☒☒ P 3.85
# Q 7m46v36  A 4.75 ☑☑☒☒ P 4.50
# Q 46m91v16 A 5.37 ☑☑☒☒ P 5.55
# Q 7m49v19  A 2.38 ☑☑☒☒ P 2.25
# Q 1m69v64  A 0.91 ☑☑☒☒ P 0.87
# Q 85m68v79 A 43.9 ☑☒☑☒ P 44.5
# Q 14m61v56 A 10.5 ☒☒☑☒ P 9..0
# Q 3m91v14  A 0.45 ☑☑☒☑ P 0.35
# Q 11m3v36  A 28.3 ☑☑☑☒ P 28.4
#
# --------------------------------------------------
# Iteration 16
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 54us/sample - loss: 0.9035 - accuracy: 0.6441 - val_loss: 0.9567 - val_accuracy: 0.6148
# Epoch 2/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.8991 - accuracy: 0.6459 - val_loss: 0.9216 - val_accuracy: 0.6285
# Epoch 3/3
# 64000/64000 [==============================] - 3s 54us/sample - loss: 0.8964 - accuracy: 0.6468 - val_loss: 0.8381 - val_accuracy: 0.6849
# score: [0.8411748955249786, 0.6835]
# Q 63m73v92 A 42.6 ☑☑☑☒ P 42.2
# Q 8m67v5   A 0.53 ☑☑☑☒ P 0.59
# Q 58m87v39 A 15.6 ☑☑☑☒ P 15.2
# Q 5m61v4   A 0.30 ☑☑☑☒ P 0.39
# Q 39m16v19 A 13.5 ☑☑☑☒ P 13.2
# Q 26m35v28 A 11.9 ☑☑☑☑ P 11.9
# Q 48m4v99  A 91.4 ☑☑☑☒ P 91.3
# Q 4m87v25  A 1.10 ☑☑☒☒ P 1.04
# Q 98m19v52 A 43.6 ☑☒☑☒ P 42.2
# Q 12m47v83 A 16.9 ☑☒☑☒ P 17.2
#
# --------------------------------------------------
# Iteration 17
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.8935 - accuracy: 0.6487 - val_loss: 0.8846 - val_accuracy: 0.6535
# Epoch 2/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.8901 - accuracy: 0.6498 - val_loss: 0.9019 - val_accuracy: 0.6378
# Epoch 3/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.8868 - accuracy: 0.6501 - val_loss: 0.9092 - val_accuracy: 0.6358
# score: [0.9126605043411254, 0.6346875]
# Q 44m58v11 A 4.75 ☑☑☒☒ P 4.34
# Q 4m15v18  A 3.79 ☑☑☒☒ P 3.40
# Q 73m8v46  A 41.5 ☑☑☑☒ P 41.0
# Q 49m49v8  A 4.00 ☒☑☒☑ P 3.40
# Q 15m98v1  A 0.13 ☑☑☑☑ P 0.13
# Q 34m42v92 A 41.2 ☑☑☑☒ P 41.0
# Q 73m57v1  A 0.56 ☑☑☑☒ P 0.59
# Q 92m4v72  A 69.0 ☑☑☑☒ P 69.8
# Q 27m26v11 A 5.60 ☑☑☒☑ P 5.40
# Q 48m36v52 A 29.7 ☑☑☑☒ P 29.0
#
# --------------------------------------------------
# Iteration 18
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.8848 - accuracy: 0.6518 - val_loss: 0.9353 - val_accuracy: 0.6317
# Epoch 2/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.8800 - accuracy: 0.6530 - val_loss: 0.8830 - val_accuracy: 0.6453
# Epoch 3/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.8775 - accuracy: 0.6554 - val_loss: 0.8650 - val_accuracy: 0.6513
# score: [0.8683820173740388, 0.6547812]
# Q 32m83v77 A 21.4 ☑☑☑☒ P 21.5
# Q 24m18v84 A 48.0 ☑☒☑☒ P 47.5
# Q 44m42v29 A 14.8 ☑☑☑☒ P 14.7
# Q 95m53v85 A 54.6 ☑☑☑☒ P 54.5
# Q 75m49v13 A 7.86 ☑☑☒☒ P 7.50
# Q 94m34v22 A 16.2 ☑☒☑☒ P 15.8
# Q 27m94v21 A 4.69 ☑☑☒☒ P 4.85
# Q 81m9v29  A 26.1 ☑☒☑☒ P 25.7
# Q 4m96v4   A 0.16 ☑☑☑☒ P 0.15
# Q 63m71v51 A 24.0 ☑☒☑☒ P 23.1
#
# --------------------------------------------------
# Iteration 19
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.8750 - accuracy: 0.6563 - val_loss: 0.9042 - val_accuracy: 0.6338
# Epoch 2/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.8711 - accuracy: 0.6583 - val_loss: 0.9117 - val_accuracy: 0.6303
# Epoch 3/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.8675 - accuracy: 0.6588 - val_loss: 0.8448 - val_accuracy: 0.6777
# score: [0.8480465919971466, 0.67634374]
# Q 45m1v1   A 0.98 ☑☑☑☒ P 0.99
# Q 34m27v4  A 2.23 ☑☑☒☒ P 2.10
# Q 38m92v31 A 9.06 ☑☑☑☒ P 9.00
# Q 75m4v96  A 91.1 ☑☑☑☒ P 91.2
# Q 6m28v74  A 13.1 ☑☒☑☒ P 12.0
# Q 84m33v79 A 56.7 ☑☒☑☒ P 57.5
# Q 56m48v59 A 31.8 ☑☑☑☒ P 31.5
# Q 73m1v91  A 89.8 ☑☑☑☒ P 89.9
# Q 33m47v6  A 2.48 ☑☑☑☒ P 2.40
# Q 94m95v59 A 29.3 ☑☑☑☒ P 29.5
#
# --------------------------------------------------
# Iteration 20
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.8654 - accuracy: 0.6614 - val_loss: 0.8941 - val_accuracy: 0.6443
# Epoch 2/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.8621 - accuracy: 0.6627 - val_loss: 0.8428 - val_accuracy: 0.6691
# Epoch 3/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.8574 - accuracy: 0.6647 - val_loss: 0.9027 - val_accuracy: 0.6385
# score: [0.9041434924602508, 0.639625]
# Q 73m8v96  A 86.5 ☑☑☑☒ P 86.4
# Q 84m9v57  A 51.5 ☑☑☑☒ P 51.7
# Q 75m3v48  A 46.2 ☑☒☑☑ P 45.2
# Q 33m53v63 A 24.2 ☑☑☑☑ P 24.2
# Q 14m2v96  A 84.0 ☑☒☑☒ P 83.4
# Q 54m61v68 A 31.9 ☑☑☑☒ P 31.5
# Q 93m29v29 A 22.1 ☑☒☑☒ P 21.2
# Q 51m63v57 A 25.5 ☑☑☑☒ P 25.7
# Q 73m18v72 A 57.8 ☑☑☑☒ P 57.2
# Q 33m27v78 A 42.9 ☑☑☑☒ P 42.5
#
# --------------------------------------------------
# Iteration 21
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.8566 - accuracy: 0.6639 - val_loss: 0.8696 - val_accuracy: 0.6489
# Epoch 2/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.8519 - accuracy: 0.6669 - val_loss: 0.8883 - val_accuracy: 0.6467
# Epoch 3/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.8503 - accuracy: 0.6670 - val_loss: 0.8500 - val_accuracy: 0.6656
# score: [0.8575352659225464, 0.66515625]
# Q 7m78v56  A 4.61 ☑☑☒☒ P 4.80
# Q 49m27v27 A 17.4 ☑☑☑☒ P 17.9
# Q 16m51v35 A 8.36 ☑☑☒☒ P 8.80
# Q 86m76v86 A 45.7 ☑☑☑☒ P 45.5
# Q 28m64v86 A 26.2 ☑☑☑☒ P 26.5
# Q 9m94v78  A 6.82 ☑☑☑☒ P 6.84
# Q 81m14v15 A 12.8 ☑☑☑☒ P 12.9
# Q 72m83v8  A 3.72 ☑☑☒☒ P 3.50
# Q 22m72v32 A 7.49 ☑☑☒☒ P 7.25
# Q 51m96v42 A 14.6 ☑☑☑☒ P 14.2
#
# --------------------------------------------------
# Iteration 22
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.8481 - accuracy: 0.6671 - val_loss: 0.8614 - val_accuracy: 0.6524
# Epoch 2/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.8441 - accuracy: 0.6686 - val_loss: 0.8313 - val_accuracy: 0.6772
# Epoch 3/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.8413 - accuracy: 0.6705 - val_loss: 0.8670 - val_accuracy: 0.6530
# score: [0.8713283448219299, 0.6506562]
# Q 63m64v84 A 41.7 ☑☑☑☒ P 41.0
# Q 27m36v48 A 20.6 ☑☑☑☒ P 20.0
# Q 32m75v74 A 22.1 ☑☑☑☒ P 22.0
# Q 69m31v19 A 13.1 ☑☒☑☒ P 12.9
# Q 2m83v8   A 0.19 ☑☑☒☑ P 0.29
# Q 88m75v5  A 2.70 ☑☑☒☑ P 2.60
# Q 82m64v48 A 27.0 ☑☒☑☒ P 26.7
# Q 3m65v76  A 3.35 ☑☑☒☒ P 3.50
# Q 5m8v22   A 8.46 ☑☑☒☒ P 8.00
# Q 77m84v17 A 8.13 ☑☑☒☒ P 8.40
#
# --------------------------------------------------
# Iteration 23
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.8392 - accuracy: 0.6717 - val_loss: 0.8157 - val_accuracy: 0.6826
# Epoch 2/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.8348 - accuracy: 0.6740 - val_loss: 0.9047 - val_accuracy: 0.6494
# Epoch 3/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.8335 - accuracy: 0.6741 - val_loss: 0.9128 - val_accuracy: 0.6431
# score: [0.9237109456062317, 0.6393125]
# Q 35m61v71 A 25.9 ☑☒☑☒ P 26.1
# Q 72m41v69 A 44.0 ☑☑☑☑ P 44.0
# Q 38m67v16 A 5.79 ☑☑☒☒ P 5.20
# Q 76m49v79 A 48.0 ☑☑☑☑ P 48.0
# Q 15m9v61  A 38.1 ☑☒☑☒ P 39.4
# Q 15m21v52 A 21.7 ☑☒☑☒ P 22.2
# Q 71m12v83 A 71.0 ☑☑☑☒ P 71.2
# Q 56m28v53 A 35.3 ☑☒☑☒ P 36.6
# Q 41m41v87 A 43.5 ☑☑☑☒ P 43.0
# Q 25m21v2  A 1.09 ☑☑☒☒ P 1.10
#
# --------------------------------------------------
# Iteration 24
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.8321 - accuracy: 0.6745 - val_loss: 0.8084 - val_accuracy: 0.6846
# Epoch 2/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.8283 - accuracy: 0.6752 - val_loss: 0.8594 - val_accuracy: 0.6568
# Epoch 3/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.8251 - accuracy: 0.6769 - val_loss: 0.9002 - val_accuracy: 0.6420
# score: [0.9047714221477509, 0.641625]
# Q 55m85v68 A 26.7 ☑☒☑☒ P 27.5
# Q 62m6v84  A 76.6 ☑☑☑☒ P 76.9
# Q 69m12v84 A 71.6 ☑☒☑☒ P 70.8
# Q 73m9v1   A 0.89 ☑☑☑☑ P 0.89
# Q 96m1v82  A 81.2 ☑☑☑☒ P 81.1
# Q 46m7v93  A 80.7 ☑☒☑☒ P 81.8
# Q 82m27v35 A 26.3 ☑☑☑☒ P 26.6
# Q 65m15v97 A 78.8 ☑☑☑☒ P 78.0
# Q 18m9v45  A 30.0 ☑☑☑☒ P 30.8
# Q 45m55v32 A 14.4 ☑☑☑☒ P 14.0
#
# --------------------------------------------------
# Iteration 25
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.8223 - accuracy: 0.6785 - val_loss: 0.8059 - val_accuracy: 0.6828
# Epoch 2/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.8206 - accuracy: 0.6806 - val_loss: 0.8542 - val_accuracy: 0.6655
# Epoch 3/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.8177 - accuracy: 0.6805 - val_loss: 0.8360 - val_accuracy: 0.6701
# score: [0.8421741099357605, 0.66840625]
# Q 4m99v76  A 2.95 ☒☑☒☑ P 3.05
# Q 53m73v48 A 20.2 ☑☑☑☒ P 20.5
# Q 3m6v71   A 23.7 ☑☒☑☒ P 24.8
# Q 54m32v45 A 28.3 ☑☑☑☒ P 28.1
# Q 64m73v13 A 6.07 ☑☑☒☒ P 6.54
# Q 3m6v71   A 23.7 ☑☒☑☒ P 24.8
# Q 76m31v72 A 51.1 ☑☑☑☒ P 51.5
# Q 47m61v15 A 6.53 ☑☑☒☒ P 6.44
# Q 36m39v87 A 41.8 ☑☑☑☒ P 41.4
# Q 76m8v26  A 23.5 ☑☑☑☒ P 23.2
#
# --------------------------------------------------
# Iteration 26
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.8158 - accuracy: 0.6812 - val_loss: 0.8141 - val_accuracy: 0.6781
# Epoch 2/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.8147 - accuracy: 0.6822 - val_loss: 0.8510 - val_accuracy: 0.6649
# Epoch 3/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.8116 - accuracy: 0.6829 - val_loss: 0.8672 - val_accuracy: 0.6585
# score: [0.8769088108539581, 0.655]
# Q 33m85v64 A 17.9 ☑☒☑☒ P 18.5
# Q 98m65v41 A 24.7 ☑☑☑☒ P 24.6
# Q 36m18v44 A 29.3 ☒☒☑☒ P 30.5
# Q 64m22v96 A 71.4 ☑☒☑☒ P 70.0
# Q 96m75v93 A 52.2 ☑☒☑☒ P 51.5
# Q 91m94v7  A 3.44 ☑☑☒☒ P 3.50
# Q 62m93v66 A 26.4 ☑☒☑☒ P 27.5
# Q 91m17v1  A 0.84 ☑☑☑☒ P 0.83
# Q 87m75v96 A 51.6 ☑☑☑☒ P 51.0
# Q 88m57v47 A 28.5 ☑☑☑☒ P 28.2
#
# --------------------------------------------------
# Iteration 27
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.8093 - accuracy: 0.6845 - val_loss: 0.8278 - val_accuracy: 0.6751
# Epoch 2/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.8062 - accuracy: 0.6849 - val_loss: 0.8493 - val_accuracy: 0.6620
# Epoch 3/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.8051 - accuracy: 0.6856 - val_loss: 0.8065 - val_accuracy: 0.6852
# score: [0.8122373790740967, 0.6831875]
# Q 52m37v31 A 18.1 ☑☑☑☒ P 18.9
# Q 7m5v46   A 26.8 ☑☑☑☒ P 26.0
# Q 3m39v86  A 6.14 ☒☑☒☒ P 5.00
# Q 17m49v48 A 12.4 ☑☑☑☒ P 12.0
# Q 31m4v28  A 24.8 ☑☑☑☒ P 24.1
# Q 38m48v21 A 9.28 ☑☑☒☒ P 9.10
# Q 3m46v6   A 0.37 ☑☑☑☒ P 0.31
# Q 56m37v9  A 5.42 ☑☑☒☑ P 5.82
# Q 34m44v94 A 41.0 ☑☑☑☑ P 41.0
# Q 19m8v31  A 21.8 ☑☑☑☒ P 21.0
#
# --------------------------------------------------
# Iteration 28
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.8024 - accuracy: 0.6880 - val_loss: 0.8196 - val_accuracy: 0.6795
# Epoch 2/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.8003 - accuracy: 0.6886 - val_loss: 0.7825 - val_accuracy: 0.6968
# Epoch 3/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.7970 - accuracy: 0.6896 - val_loss: 0.8603 - val_accuracy: 0.6541
# score: [0.8619791390895843, 0.6553125]
# Q 47m61v15 A 6.53 ☑☑☒☒ P 6.40
# Q 1m16v87  A 5.12 ☑☑☒☒ P 5.80
# Q 6m81v58  A 4.00 ☒☑☑☒ P 3.07
# Q 12m88v48 A 5.76 ☑☑☒☒ P 5.00
# Q 9m24v12  A 3.27 ☑☑☒☒ P 3.30
# Q 59m28v89 A 60.4 ☑☒☑☒ P 61.8
# Q 4m44v95  A 7.92 ☒☑☒☒ P 8.30
# Q 95m29v44 A 33.7 ☑☒☑☒ P 34.6
# Q 21m94v75 A 13.7 ☑☑☑☒ P 13.8
# Q 33m84v54 A 15.2 ☑☑☑☒ P 15.6
#
# --------------------------------------------------
# Iteration 29
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.7968 - accuracy: 0.6892 - val_loss: 0.8011 - val_accuracy: 0.6839
# Epoch 2/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.7933 - accuracy: 0.6912 - val_loss: 0.7790 - val_accuracy: 0.7007
# Epoch 3/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.7912 - accuracy: 0.6922 - val_loss: 0.8063 - val_accuracy: 0.6852
# score: [0.8171635782718658, 0.68090624]
# Q 71m18v14 A 11.2 ☑☑☑☒ P 11.3
# Q 82m34v99 A 70.0 ☑☒☑☑ P 79.0
# Q 95m61v74 A 45.1 ☑☑☑☒ P 45.5
# Q 64m49v68 A 38.5 ☑☒☑☒ P 39.0
# Q 73m51v18 A 10.6 ☑☑☑☑ P 10.6
# Q 77m86v47 A 22.2 ☑☑☑☒ P 22.5
# Q 82m92v86 A 40.5 ☑☑☑☒ P 40.0
# Q 28m4v51  A 44.6 ☑☑☑☒ P 44.4
# Q 93m54v16 A 10.1 ☑☑☑☒ P 10.3
# Q 86m21v16 A 12.9 ☑☒☑☒ P 13.0
#
# --------------------------------------------------
# Iteration 30
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.7904 - accuracy: 0.6917 - val_loss: 0.7751 - val_accuracy: 0.6949
# Epoch 2/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.7890 - accuracy: 0.6924 - val_loss: 0.8681 - val_accuracy: 0.6618
# Epoch 3/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.7867 - accuracy: 0.6951 - val_loss: 0.7965 - val_accuracy: 0.6877
# score: [0.7997347369194031, 0.68575]
# Q 43m92v92 A 29.3 ☑☑☑☒ P 29.4
# Q 33m16v85 A 57.2 ☑☑☑☒ P 57.4
# Q 81m29v8  A 5.89 ☑☑☒☒ P 5.04
# Q 19m6v48  A 36.5 ☑☑☑☒ P 36.9
# Q 61m99v52 A 19.8 ☑☑☑☒ P 19.1
# Q 22m12v99 A 64.1 ☑☑☑☒ P 64.0
# Q 54m61v15 A 7.04 ☑☑☑☒ P 7.00
# Q 6m9v74   A 29.6 ☑☒☑☒ P 28.5
# Q 45m42v21 A 10.9 ☑☑☑☒ P 10.6
# Q 86m48v66 A 42.4 ☑☑☑☒ P 42.5
#
# --------------------------------------------------
# Iteration 31
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.7841 - accuracy: 0.6948 - val_loss: 0.8175 - val_accuracy: 0.6753
# Epoch 2/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.7825 - accuracy: 0.6950 - val_loss: 0.7996 - val_accuracy: 0.6872
# Epoch 3/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.7808 - accuracy: 0.6955 - val_loss: 0.8022 - val_accuracy: 0.6781
# score: [0.811348799943924, 0.67459375]
# Q 4m27v74  A 9.55 ☑☑☒☒ P 9.80
# Q 71m36v72 A 47.8 ☑☒☑☒ P 48.1
# Q 48m45v36 A 18.6 ☑☑☑☒ P 18.1
# Q 73m35v92 A 62.2 ☑☒☑☒ P 63.0
# Q 42m75v21 A 7.54 ☑☑☒☒ P 7.20
# Q 69m76v53 A 25.2 ☑☑☑☒ P 25.1
# Q 18m33v98 A 34.6 ☑☑☑☒ P 34.5
# Q 52m28v32 A 20.8 ☑☒☑☒ P 21.0
# Q 45m99v88 A 27.5 ☑☑☑☒ P 27.6
# Q 79m31v15 A 10.8 ☑☑☑☑ P 10.8
#
# --------------------------------------------------
# Iteration 32
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.7790 - accuracy: 0.6962 - val_loss: 0.7510 - val_accuracy: 0.7111
# Epoch 2/3
# 64000/64000 [==============================] - 3s 54us/sample - loss: 0.7762 - accuracy: 0.6986 - val_loss: 0.7730 - val_accuracy: 0.6996
# Epoch 3/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.7746 - accuracy: 0.6985 - val_loss: 0.7699 - val_accuracy: 0.6997
# score: [0.7761253898143768, 0.69734377]
# Q 6m16v99  A 27.0 ☑☑☑☒ P 27.2
# Q 8m53v45  A 5.90 ☒☑☒☑ P 6.20
# Q 52m42v23 A 12.7 ☑☑☑☑ P 12.7
# Q 1m71v28  A 0.39 ☑☑☑☒ P 0.34
# Q 88m4v65  A 62.2 ☑☑☑☒ P 62.8
# Q 45m82v54 A 19.1 ☑☑☑☒ P 19.2
# Q 88m77v17 A 9.07 ☑☑☒☒ P 9.10
# Q 45m11v82 A 65.9 ☑☒☑☒ P 66.3
# Q 95m25v94 A 74.4 ☑☑☑☒ P 74.9
# Q 17m25v71 A 28.7 ☑☑☑☒ P 28.4
#
# --------------------------------------------------
# Iteration 33
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.7733 - accuracy: 0.6998 - val_loss: 0.7757 - val_accuracy: 0.6951
# Epoch 2/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.7694 - accuracy: 0.7002 - val_loss: 0.8108 - val_accuracy: 0.6822
# Epoch 3/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.7688 - accuracy: 0.7009 - val_loss: 0.7538 - val_accuracy: 0.7086
# score: [0.7556837878227234, 0.70734376]
# Q 19m26v94 A 39.7 ☒☒☑☒ P 40.0
# Q 84m92v99 A 47.2 ☑☑☑☒ P 47.5
# Q 37m24v81 A 49.1 ☑☑☑☑ P 49.1
# Q 73m55v65 A 37.1 ☑☑☑☒ P 37.5
# Q 91m25v69 A 54.1 ☑☑☑☒ P 54.5
# Q 25m21v2  A 1.09 ☑☑☑☒ P 1.00
# Q 49m11v54 A 44.1 ☑☑☑☒ P 44.6
# Q 68m99v1  A 0.41 ☑☑☑☒ P 0.44
# Q 74m11v76 A 66.2 ☑☒☑☒ P 67.5
# Q 34m85v46 A 13.1 ☑☒☑☒ P 12.9
#
# --------------------------------------------------
# Iteration 34
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.7687 - accuracy: 0.7010 - val_loss: 0.8123 - val_accuracy: 0.6769
# Epoch 2/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.7654 - accuracy: 0.7029 - val_loss: 0.8077 - val_accuracy: 0.6881
# Epoch 3/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.7644 - accuracy: 0.7024 - val_loss: 0.7776 - val_accuracy: 0.6940
# score: [0.7884940972328186, 0.6900625]
# Q 61m81v36 A 15.5 ☑☑☑☒ P 15.0
# Q 9m42v63  A 11.1 ☑☑☑☒ P 11.3
# Q 86m25v56 A 43.4 ☑☑☑☒ P 43.5
# Q 73m29v3  A 2.15 ☑☑☒☑ P 2.25
# Q 9m9v94   A 47.0 ☑☑☑☒ P 47.5
# Q 69m1v31  A 30.6 ☑☑☑☒ P 30.5
# Q 73m34v85 A 58.0 ☑☒☑☒ P 57.5
# Q 2m66v55  A 1.62 ☑☑☒☒ P 1.77
# Q 3m94v21  A 0.65 ☑☑☑☒ P 0.69
# Q 19m17v98 A 51.7 ☑☑☑☒ P 51.0
#
# --------------------------------------------------
# Iteration 35
# Train on 64000 samples, validate on 8000 samples
# Epoch 1/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.7626 - accuracy: 0.7042 - val_loss: 0.7981 - val_accuracy: 0.6828
# Epoch 2/3
# 64000/64000 [==============================] - 3s 52us/sample - loss: 0.7598 - accuracy: 0.7053 - val_loss: 0.7833 - val_accuracy: 0.6877
# Epoch 3/3
# 64000/64000 [==============================] - 3s 53us/sample - loss: 0.7592 - accuracy: 0.7050 - val_loss: 0.8156 - val_accuracy: 0.6865
# score: [0.8191725904941559, 0.6844375]
# Q 17m16v34 A 17.5 ☑☑☑☒ P 17.6
# Q 68m65v51 A 26.1 ☑☑☑☒ P 26.6
# Q 27m9v73  A 54.8 ☑☑☑☑ P 54.8
# Q 65m97v62 A 24.9 ☑☒☑☒ P 25.1
# Q 99m66v74 A 44.4 ☑☑☑☒ P 44.5
# Q 34m97v49 A 12.7 ☑☑☑☒ P 12.9
# Q 36m18v56 A 37.3 ☑☑☑☒ P 37.0
# Q 29m36v75 A 33.5 ☑☑☑☒ P 33.0
# Q 32m32v94 A 47.0 ☑☑☑☑ P 47.0
# Q 26m66v59 A 16.7 ☑☒☑☒ P 17.6
